# %% [markdown]
# <a href="https://colab.research.google.com/github/HemaP-0303/LAB_AI/blob/main/1BM22CS111_Week5_STIMULATED_ANNEALING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import math

# Function to calculate the number of attacking pairs
def calculate_cost(state):
    attacking_pairs = 0
    n = len(state)
    for i in range(n):
        for j in range(i + 1, n):
            # Check if two queens are attacking each other
            if state[i] == state[j] or abs(state[i] - state[j]) == abs(i - j):
                attacking_pairs += 1
    return attacking_pairs

# Function to generate a random neighbor by moving a random queen to a different row
def generate_neighbor(state):
    neighbor = state[:]
    column = random.randint(0, len(state) - 1)
    new_row = random.randint(0, len(state) - 1)
    while new_row == state[column]:
        new_row = random.randint(0, len(state) - 1)
    neighbor[column] = new_row
    return neighbor

# Simulated Annealing algorithm
def simulated_annealing(n, initial_temperature, cooling_factor, max_iterations):
    # Step 1: Initialize a random arrangement of queens
    current_state = [random.randint(0, n-1) for _ in range(n)]
    current_cost = calculate_cost(current_state)
    best_state = current_state
    best_cost = current_cost
    temperature = initial_temperature

    print(f"Initial state: {current_state} with cost: {current_cost}")

    iteration = 0
    while iteration < max_iterations and temperature > 0:
        # Step 2: Generate a random neighbor
        neighbor_state = generate_neighbor(current_state)
        neighbor_cost = calculate_cost(neighbor_state)

        # Step 3: Calculate the cost difference
        delta_cost = neighbor_cost - current_cost

        # Step 4: Accept or reject the new state based on the cost difference
        if delta_cost < 0:
            current_state = neighbor_state
            current_cost = neighbor_cost
        else:
            acceptance_probability = math.exp(-delta_cost / temperature)
            if random.random() < acceptance_probability:
                current_state = neighbor_state
                current_cost = neighbor_cost

        # Track the best state
        if current_cost < best_cost:
            best_state = current_state
            best_cost = current_cost

        # Print the state and cost at each iteration
        print(f"Iteration {iteration+1}: {current_state} with cost: {current_cost}")

        # Step 5: Cool down the temperature
        temperature *= cooling_factor
        iteration += 1

    return best_state, best_cost

# Main function to run the algorithm
if __name__ == "__main__":
    N = 4  # Number of queens (4x4 board)
    initial_temperature = 100  # Initial temperature
    cooling_factor = 0.95  # Cooling factor
    max_iterations = 200  # Maximum number of iterations

    best_state, best_cost = simulated_annealing(N, initial_temperature, cooling_factor, max_iterations)

    print(f"\nFinal solution: {best_state} with cost: {best_cost}")
# Out:
# Initial state: [1, 3, 0, 3] with cost: 1
# Iteration 1: [1, 3, 0, 2] with cost: 0
# Iteration 2: [1, 3, 3, 2] with cost: 3
# Iteration 3: [1, 2, 3, 2] with cost: 5
# Iteration 4: [2, 2, 3, 2] with cost: 5
# Iteration 5: [2, 0, 3, 2] with cost: 3
# Iteration 6: [2, 1, 3, 2] with cost: 3
# Iteration 7: [2, 1, 1, 2] with cost: 4
# Iteration 8: [2, 2, 1, 2] with cost: 5
# Iteration 9: [2, 1, 1, 2] with cost: 4
# Iteration 10: [2, 2, 1, 2] with cost: 5
# Iteration 11: [2, 2, 2, 2] with cost: 6
# Iteration 12: [2, 3, 2, 2] with cost: 5
# Iteration 13: [2, 1, 2, 2] with cost: 5
# Iteration 14: [2, 1, 2, 3] with cost: 5
# Iteration 15: [2, 1, 3, 3] with cost: 3
# Iteration 16: [2, 2, 3, 3] with cost: 3
# Iteration 17: [2, 3, 3, 3] with cost: 4
# Iteration 18: [2, 0, 3, 3] with cost: 1
# Iteration 19: [2, 1, 3, 3] with cost: 3
# Iteration 20: [2, 1, 3, 0] with cost: 1
# Iteration 21: [2, 1, 0, 0] with cost: 4
# Iteration 22: [2, 0, 0, 0] with cost: 4
# Iteration 23: [2, 1, 0, 0] with cost: 4
# Iteration 24: [2, 3, 0, 0] with cost: 3
# Iteration 25: [2, 3, 0, 3] with cost: 3
# Iteration 26: [2, 1, 0, 3] with cost: 4
# Iteration 27: [2, 1, 1, 3] with cost: 3
# Iteration 28: [2, 3, 1, 3] with cost: 2
# Iteration 29: [2, 1, 1, 3] with cost: 3
# Iteration 30: [2, 1, 2, 3] with cost: 5
# Iteration 31: [2, 1, 2, 1] with cost: 5
# Iteration 32: [2, 1, 2, 2] with cost: 5
# Iteration 33: [2, 3, 2, 2] with cost: 5
# Iteration 34: [2, 3, 2, 1] with cost: 5
# Iteration 35: [2, 3, 3, 1] with cost: 3
# Iteration 36: [2, 1, 3, 1] with cost: 2
# Iteration 37: [2, 3, 3, 1] with cost: 3
# Iteration 38: [2, 3, 3, 1] with cost: 3
# Iteration 39: [2, 3, 2, 1] with cost: 5
# Iteration 40: [2, 3, 2, 2] with cost: 5
# Iteration 41: [1, 3, 2, 2] with cost: 2
# Iteration 42: [1, 2, 2, 2] with cost: 4
# Iteration 43: [1, 2, 2, 2] with cost: 4
# Iteration 44: [0, 2, 2, 2] with cost: 4
# Iteration 45: [0, 3, 2, 2] with cost: 3
# Iteration 46: [0, 3, 1, 2] with cost: 1
# Iteration 47: [0, 3, 1, 3] with cost: 2
# Iteration 48: [0, 0, 1, 3] with cost: 3
# Iteration 49: [1, 0, 1, 3] with cost: 3
# Iteration 50: [1, 2, 1, 3] with cost: 3
# Iteration 51: [1, 3, 1, 3] with cost: 2
# Iteration 52: [1, 1, 1, 3] with cost: 4
# Iteration 53: [1, 1, 1, 1] with cost: 6
# Iteration 54: [1, 1, 1, 3] with cost: 4
# Iteration 55: [1, 1, 1, 0] with cost: 4
# Iteration 56: [1, 1, 3, 0] with cost: 2
# Iteration 57: [1, 3, 3, 0] with cost: 2
# Iteration 58: [1, 1, 3, 0] with cost: 2
# Iteration 59: [0, 1, 3, 0] with cost: 2
# Iteration 60: [0, 1, 3, 0] with cost: 2
# Iteration 61: [0, 0, 3, 0] with cost: 3
# Iteration 62: [0, 0, 3, 1] with cost: 1
# Iteration 63: [0, 3, 3, 1] with cost: 2
# Iteration 64: [3, 3, 3, 1] with cost: 4
# Iteration 65: [0, 3, 3, 1] with cost: 2
# Iteration 66: [0, 3, 3, 1] with cost: 2
# Iteration 67: [0, 3, 3, 1] with cost: 2
# Iteration 68: [2, 3, 3, 1] with cost: 3
# Iteration 69: [2, 3, 1, 1] with cost: 3
# Iteration 70: [2, 3, 1, 3] with cost: 2
# Iteration 71: [1, 3, 1, 3] with cost: 2
# Iteration 72: [1, 3, 1, 2] with cost: 2
# Iteration 73: [1, 3, 1, 0] with cost: 2
# Iteration 74: [1, 3, 0, 0] with cost: 1
# Iteration 75: [1, 3, 0, 0] with cost: 1
# Iteration 76: [1, 3, 0, 3] with cost: 1
# Iteration 77: [1, 3, 0, 3] with cost: 1
# Iteration 78: [1, 3, 0, 0] with cost: 1
# Iteration 79: [1, 3, 0, 2] with cost: 0
# Iteration 80: [0, 3, 0, 2] with cost: 1
# Iteration 81: [0, 3, 0, 2] with cost: 1
# Iteration 82: [0, 3, 1, 2] with cost: 1
# Iteration 83: [0, 3, 1, 2] with cost: 1
# Iteration 84: [0, 3, 1, 2] with cost: 1
# Iteration 85: [0, 3, 0, 2] with cost: 1
# Iteration 86: [0, 3, 0, 2] with cost: 1
# Iteration 87: [0, 3, 0, 2] with cost: 1
# Iteration 88: [0, 2, 0, 2] with cost: 2
# Iteration 89: [0, 2, 0, 2] with cost: 2
# Iteration 90: [0, 2, 0, 2] with cost: 2
# Iteration 91: [0, 2, 0, 1] with cost: 2
# Iteration 92: [0, 0, 0, 1] with cost: 4
# Iteration 93: [0, 0, 0, 3] with cost: 4
# Iteration 94: [3, 0, 0, 3] with cost: 2
# Iteration 95: [3, 0, 0, 3] with cost: 2
# Iteration 96: [3, 2, 0, 3] with cost: 2
# Iteration 97: [3, 2, 0, 3] with cost: 2
# Iteration 98: [3, 2, 0, 3] with cost: 2
# Iteration 99: [3, 2, 0, 3] with cost: 2
# Iteration 100: [0, 2, 0, 3] with cost: 2
# Iteration 101: [0, 2, 0, 3] with cost: 2
# Iteration 102: [0, 2, 0, 2] with cost: 2
# Iteration 103: [0, 3, 0, 2] with cost: 1
# Iteration 104: [0, 3, 0, 2] with cost: 1
# Iteration 105: [0, 3, 0, 2] with cost: 1
# Iteration 106: [0, 3, 0, 2] with cost: 1
# Iteration 107: [0, 3, 0, 1] with cost: 3
# Iteration 108: [0, 2, 0, 1] with cost: 2
# Iteration 109: [0, 2, 0, 1] with cost: 2
# Iteration 110: [0, 2, 0, 1] with cost: 2
# Iteration 111: [0, 2, 0, 1] with cost: 2
# Iteration 112: [0, 2, 0, 1] with cost: 2
# Iteration 113: [0, 2, 1, 1] with cost: 2
# Iteration 114: [0, 2, 1, 1] with cost: 2
# Iteration 115: [0, 2, 0, 1] with cost: 2
# Iteration 116: [0, 2, 0, 1] with cost: 2
# Iteration 117: [0, 2, 0, 1] with cost: 2
# Iteration 118: [0, 2, 1, 1] with cost: 2
# Iteration 119: [0, 2, 1, 1] with cost: 2
# Iteration 120: [0, 2, 1, 1] with cost: 2
# Iteration 121: [0, 2, 1, 3] with cost: 2
# Iteration 122: [0, 2, 1, 3] with cost: 2
# Iteration 123: [0, 2, 0, 3] with cost: 2
# Iteration 124: [0, 2, 0, 3] with cost: 2
# Iteration 125: [2, 2, 0, 3] with cost: 2
# Iteration 126: [1, 2, 0, 3] with cost: 1
# Iteration 127: [1, 2, 0, 3] with cost: 1
# Iteration 128: [1, 2, 0, 3] with cost: 1
# Iteration 129: [1, 2, 0, 3] with cost: 1
# Iteration 130: [1, 2, 0, 3] with cost: 1
# Iteration 131: [1, 2, 0, 3] with cost: 1
# Iteration 132: [1, 2, 0, 3] with cost: 1
# Iteration 133: [1, 2, 0, 3] with cost: 1
# Iteration 134: [1, 2, 0, 3] with cost: 1
# Iteration 135: [1, 2, 0, 3] with cost: 1
# Iteration 136: [1, 2, 0, 3] with cost: 1
# Iteration 137: [1, 2, 0, 3] with cost: 1
# Iteration 138: [1, 2, 0, 3] with cost: 1
# Iteration 139: [1, 2, 0, 3] with cost: 1
# Iteration 140: [1, 2, 0, 3] with cost: 1
# Iteration 141: [1, 2, 0, 3] with cost: 1
# Iteration 142: [1, 2, 0, 3] with cost: 1
# Iteration 143: [1, 2, 0, 3] with cost: 1
# Iteration 144: [1, 2, 0, 3] with cost: 1
# Iteration 145: [1, 2, 0, 3] with cost: 1
# Iteration 146: [1, 2, 0, 3] with cost: 1
# Iteration 147: [1, 2, 0, 3] with cost: 1
# Iteration 148: [1, 2, 0, 3] with cost: 1
# Iteration 149: [1, 2, 0, 3] with cost: 1
# Iteration 150: [1, 2, 0, 3] with cost: 1
# Iteration 151: [1, 2, 0, 3] with cost: 1
# Iteration 152: [1, 3, 0, 3] with cost: 1
# Iteration 153: [1, 3, 0, 3] with cost: 1
# Iteration 154: [1, 3, 0, 3] with cost: 1
# Iteration 155: [1, 3, 0, 3] with cost: 1
# Iteration 156: [1, 3, 0, 2] with cost: 0
# Iteration 157: [1, 3, 0, 2] with cost: 0
# Iteration 158: [1, 3, 0, 2] with cost: 0
# Iteration 159: [1, 3, 0, 2] with cost: 0
# Iteration 160: [1, 3, 0, 2] with cost: 0
# Iteration 161: [1, 3, 0, 2] with cost: 0
# Iteration 162: [1, 3, 0, 2] with cost: 0
# Iteration 163: [1, 3, 0, 2] with cost: 0
# Iteration 164: [1, 3, 0, 2] with cost: 0
# Iteration 165: [1, 3, 0, 2] with cost: 0
# Iteration 166: [1, 3, 0, 2] with cost: 0
# Iteration 167: [1, 3, 0, 2] with cost: 0
# Iteration 168: [1, 3, 0, 2] with cost: 0
# Iteration 169: [1, 3, 0, 2] with cost: 0
# Iteration 170: [1, 3, 0, 2] with cost: 0
# Iteration 171: [1, 3, 0, 2] with cost: 0
# Iteration 172: [1, 3, 0, 2] with cost: 0
# Iteration 173: [1, 3, 0, 2] with cost: 0
# Iteration 174: [1, 3, 0, 2] with cost: 0
# Iteration 175: [1, 3, 0, 2] with cost: 0
# Iteration 176: [1, 3, 0, 2] with cost: 0
# Iteration 177: [1, 3, 0, 2] with cost: 0
# Iteration 178: [1, 3, 0, 2] with cost: 0
# Iteration 179: [1, 3, 0, 2] with cost: 0
# Iteration 180: [1, 3, 0, 2] with cost: 0
# Iteration 181: [1, 3, 0, 2] with cost: 0
# Iteration 182: [1, 3, 0, 2] with cost: 0
# Iteration 183: [1, 3, 0, 2] with cost: 0
# Iteration 184: [1, 3, 0, 2] with cost: 0
# Iteration 185: [1, 3, 0, 2] with cost: 0
# Iteration 186: [1, 3, 0, 2] with cost: 0
# Iteration 187: [1, 3, 0, 2] with cost: 0
# Iteration 188: [1, 3, 0, 2] with cost: 0
# Iteration 189: [1, 3, 0, 2] with cost: 0
# Iteration 190: [1, 3, 0, 2] with cost: 0
# Iteration 191: [1, 3, 0, 2] with cost: 0
# Iteration 192: [1, 3, 0, 2] with cost: 0
# Iteration 193: [1, 3, 0, 2] with cost: 0
# Iteration 194: [1, 3, 0, 2] with cost: 0
# Iteration 195: [1, 3, 0, 2] with cost: 0
# Iteration 196: [1, 3, 0, 2] with cost: 0
# Iteration 197: [1, 3, 0, 2] with cost: 0
# Iteration 198: [1, 3, 0, 2] with cost: 0
# Iteration 199: [1, 3, 0, 2] with cost: 0
# Iteration 200: [1, 3, 0, 2] with cost: 0
#
# Final solution: [1, 3, 0, 2] with cost: 0
